# %%
from dep_energy_histograms import DepEnergyHistograms

# %%
outfile = "~/dev/BetaMonitor/output/outfile_6He_1e6_bert_rdm.root"
plotter = DepEnergyHistograms(outfile)
plotter.plot(title=outfile)
plotter.print_num_events()
# Out:
# Total number of events: 4195198
# Number of events in Scintillator A (volumeid=3): 26144
# Number of events in Scintillator B (volumeid=4): 15644
# Number of events in Vaccuum (volumeid=1): 4052941
# Number of primary events: 1000000

# %%
outfile = "~/dev/BetaMonitor/output/outfile_6He_1e6.root"
plotter = DepEnergyHistograms(outfile)
plotter.plot(title=outfile)
plotter.print_num_events()
# Out:
# Total number of events: 1126042
# Number of events in Scintillator A (volumeid=3): 15139
# Number of events in Scintillator B (volumeid=4): 6545
# Number of events in Vaccuum (volumeid=1): 1046729
# Number of primary events: 1000000

# %% [markdown]
# outfile = "~/dev/BetaMonitor/output/outfile_6He_1e6_bert_rdm.root"
# plotter = DepEnergyHistograms(outfile)
# plotter.plot(title=outfile)

# %%
outfile = "~/dev/BetaMonitor/output/outfile_19Ne_1e6.root"
plotter = DepEnergyHistograms(outfile)
plotter.plot(title=outfile)
plotter.print_num_events()
# Out:
# Total number of events: 2200692
# Number of events in Scintillator A (volumeid=3): 54350
# Number of events in Scintillator B (volumeid=4): 33996
# Number of events in Vaccuum (volumeid=1): 1978792
# Number of primary events: 0

# %%
outfile = "~/dev/BetaMonitor/output/outfile_19Ne_1e6_bert_rdm.root"
plotter = DepEnergyHistograms(outfile)
plotter.plot(title=outfile)
plotter.print_num_events()
# Out:
# Total number of events: 5258730
# Number of events in Scintillator A (volumeid=3): 63325
# Number of events in Scintillator B (volumeid=4): 41270
# Number of events in Vaccuum (volumeid=1): 4983045
# Number of primary events: 0
